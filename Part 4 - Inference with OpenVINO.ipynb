# %%
from src.predict import OpenVINOPredictor

# %%
p = OpenVINOPredictor(
    model_xml="model/openvino/diarization.xml", 
    model_bin="model/openvino/diarization.bin", 
    config_path="model/configs.pth"
)

# %%
timestamps, speakers = p.predict("dataset/test/test.wav", plot=True)
# Out:
# /Users/wiradharmakencanaputra/miniconda3/envs/speaker_embedding/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
timestamps
# Out:
# array([[ 0.1919375,  2.1759375],
#        [ 2.4319375,  6.1439375],
#        [ 6.2079375,  7.5519375],
#        [ 8.5119375, 14.2719375],
#        [14.4639375, 16.8959375],
#        [17.0879375, 20.6079375],
#        [20.8639375, 26.1759375],
#        [26.4959375, 30.5279375],
#        [30.5919375, 31.5519375],
#        [31.8719375, 37.8879375],
#        [38.1439375, 38.8479375],
#        [38.9759375, 40.1919375],
#        [40.3839375, 42.4319375],
#        [42.4959375, 44.0959375],
#        [44.4159375, 48.4479375],
#        [49.1519375, 50.8159375],
#        [51.4559375, 52.0319375],
#        [52.1599375, 55.3599375]])

# %%
speakers
# Out:
# array([1, 1, 1, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 0, 0, 0, 0])
